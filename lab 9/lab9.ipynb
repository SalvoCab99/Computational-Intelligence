# %% [markdown]
# Copyright **`(c)`** 2023 Giovanni Squillero `<giovanni.squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free for personal or classroom use; see [`LICENSE.md`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %% [markdown]
# # LAB9
#
# Write a local-search algorithm (eg. an EA) able to solve the *Problem* instances 1, 2, 5, and 10 on a 1000-loci genomes, using a minimum number of fitness calls. That's all.
#
# ### Deadlines:
#
# * Submission: Sunday, December 3 ([CET](https://www.timeanddate.com/time/zones/cet))
# * Reviews: Sunday, December 10 ([CET](https://www.timeanddate.com/time/zones/cet))
#
# Notes:
#
# * Reviews will be assigned  on Monday, December 4
# * You need to commit in order to be selected as a reviewer (ie. better to commit an empty work than not to commit)

# %%
from random import choices, randint, choice, random
from functools import reduce
from collections import namedtuple
from dataclasses import dataclass
from copy import copy

from pprint import pprint

import numpy as np

import lab9_lib

# %%
POPULATION_SIZE = 100
OFFSPRING_SIZE = 30
TOURNAMENT_SIZE = 2
MUTATION_PROBABILITY = .50

NUM_SETS = 1000

# %%
fitness = lab9_lib.make_problem(1)

# %%
@dataclass
class Individual:
    fitness: tuple
    genotype: list[bool]

def select_parent(pop):
    pool = [choice(pop) for _ in range(TOURNAMENT_SIZE)]
    champion = max(pool, key=lambda i: i.fitness)
    return champion

#MUTATION 3 types
def mutate(ind: Individual) -> Individual:              #STANDARD MUTATION
    offspring = copy(ind)
    pos = randint(0, NUM_SETS-1)
    offspring.genotype[pos] = not offspring.genotype[pos]
    offspring.fitness = None
    return offspring

def n_mutate(ind: Individual, n) -> Individual:         #mutate in n positions (n = random(2,NUM_SETS/10))
    offspring = copy(ind)
    positions = [randint(0, NUM_SETS-1) for _ in range(n)]
    for pos in positions:
        offspring.genotype[pos] = not offspring.genotype[pos]
    offspring.fitness = None
    return offspring

def little_reverse(ind: Individual, n) -> Individual:   #reverse a slice of array, n is the lenght of slice(n = random(2,NUM_SETS/10)) 
    offspring = copy(ind)
    pos = randint(0, NUM_SETS-n)
    offspring.genotype[pos: pos+n] = reversed(offspring.genotype[pos: pos+n])
    offspring.fitness = None
    return offspring


#CROSSOVER 3 types
def one_cut_xover(ind1: Individual, ind2: Individual) -> Individual:        #STANDARD one cut crossover
    cut_point = randint(0, NUM_SETS-1)
    offspring = Individual(fitness=None,
                           genotype=ind1.genotype[:cut_point] + ind2.genotype[cut_point:])
    assert len(offspring.genotype) == NUM_SETS
    return offspring

def n_cut_xover(ind1: Individual, ind2: Individual, n: int) -> Individual:  #n cut crossover (n = random(2,NUM_SETS/10))
    cut_points = sorted({0, NUM_SETS-1} | {randint(1, NUM_SETS-2) for _ in range(n)})
    offspring_genotype = []
    current_parent = ind1

    for i, cut_point in enumerate(cut_points):
        end_point = cut_points[i + 1] if i + 1 < len(cut_points) else NUM_SETS
        offspring_genotype.extend(current_parent.genotype[cut_point:end_point])
        current_parent = ind2 if current_parent is ind1 else ind1

    offspring = Individual(fitness=None, genotype=offspring_genotype)
    assert len(offspring.genotype) == NUM_SETS
    return offspring


def uniform_xover(ind1: Individual, ind2: Individual) -> Individual:        #each element is randomly given by the first inidividual or the second
    offspring_genotype = [choice([ind1.genotype[i], ind2.genotype[i]]) for i in range(NUM_SETS)]
    offspring = Individual(fitness=None, genotype=offspring_genotype)
    assert len(offspring.genotype) == NUM_SETS
    return offspring

# %%
population = [
    Individual(
        genotype=[choice((0, 1)) for _ in range(NUM_SETS)],
        fitness=None,
    )
    for _ in range(POPULATION_SIZE)
]

for i in population:
    i.fitness = fitness(i.genotype)
'''
for ind in population:
    print(f"{''.join(str(g) for g in ind.genotype)}: {ind.fitness:.2%}")
'''
# Out:
# '\nfor ind in population:\n    print(f"{\'\'.join(str(g) for g in ind.genotype)}: {ind.fitness:.2%}")\n'

# %%
previous_fitness = 0
same_fintness_counter = 1
for generation in range(1000):
    offspring = list()
    for counter in range(OFFSPRING_SIZE):
        if random() < MUTATION_PROBABILITY:  # self-adapt mutation probability
            # three types of mutation 
            p = select_parent(population)
            o = choice([mutate(p), n_mutate(p, randint(2,int(NUM_SETS/10))), little_reverse(p, randint(2,int(NUM_SETS/10)))])   #randomly selected
        else:
            # three types of xover
            p1 = select_parent(population)
            p2 = select_parent(population)
            o = choice([one_cut_xover(p1, p2), uniform_xover(p1,p2), n_cut_xover(p1,p2,randint(2,int(NUM_SETS/10)))])           #randomly selected
        offspring.append(o)

    for i in offspring:
        i.fitness = fitness(i.genotype)
    population.extend(offspring)
    population.sort(key=lambda i: i.fitness, reverse=True)
    population = population[:POPULATION_SIZE]           #removes individuals which have the lowest fitness
    print(f"best fitness: {population[0].fitness:.2%} at generation number {generation}, same fitness {same_fintness_counter}")

    if (population[0].fitness==1 or same_fintness_counter > 149):   #stop populating if the fitness is 100% or if there is always the same fitness in 150 population
        break
    if (previous_fitness == population[0].fitness):
        same_fintness_counter = same_fintness_counter + 1
    else :
        previous_fitness = population[0].fitness
        same_fintness_counter = 1
print(f"all fitness call: {fitness.calls}")
# Out:
# best fitness: 54.70% at generation number 0, same fitness 1
# best fitness: 54.70% at generation number 1, same fitness 1
# best fitness: 54.70% at generation number 2, same fitness 2
# best fitness: 54.70% at generation number 3, same fitness 3
# best fitness: 54.80% at generation number 4, same fitness 4
# best fitness: 54.80% at generation number 5, same fitness 1
# best fitness: 56.00% at generation number 6, same fitness 2
# best fitness: 56.00% at generation number 7, same fitness 1
# best fitness: 57.30% at generation number 8, same fitness 2
# best fitness: 57.30% at generation number 9, same fitness 1
# best fitness: 57.30% at generation number 10, same fitness 2
# best fitness: 57.30% at generation number 11, same fitness 3
# best fitness: 57.60% at generation number 12, same fitness 4
# best fitness: 58.20% at generation number 13, same fitness 1
# best fitness: 58.20% at generation number 14, same fitness 1
# best fitness: 58.20% at generation number 15, same fitness 2
# best fitness: 58.30% at generation number 16, same fitness 3
# best fitness: 58.30% at generation number 17, same fitness 1
# best fitness: 58.30% at generation number 18, same fitness 2
# best fitness: 58.30% at generation number 19, same fitness 3
# best fitness: 58.40% at generation number 20, same fitness 4
# best fitness: 58.40% at generation number 21, same fitness 1
# best fitness: 58.90% at generation number 22, same fitness 2
# best fitness: 58.90% at generation number 23, same fitness 1
# best fitness: 60.50% at generation number 24, same fitness 2
# best fitness: 60.50% at generation number 25, same fitness 1
# best fitness: 60.50% at generation number 26, same fitness 2
# best fitness: 60.50% at generation number 27, same fitness 3
# best fitness: 60.50% at generation number 28, same fitness 4
# best fitness: 60.50% at generation number 29, same fitness 5
# best fitness: 60.50% at generation number 30, same fitness 6
# best fitness: 60.50% at generation number 31, same fitness 7
# best fitness: 60.80% at generation number 32, same fitness 8
# best fitness: 61.30% at generation number 33, same fitness 1
# best fitness: 61.30% at generation number 34, same fitness 1
# best fitness: 61.30% at generation number 35, same fitness 2
# best fitness: 61.30% at generation number 36, same fitness 3
# best fitness: 61.30% at generation number 37, same fitness 4
# best fitness: 61.30% at generation number 38, same fitness 5
# best fitness: 61.30% at generation number 39, same fitness 6
# best fitness: 61.30% at generation number 40, same fitness 7
# best fitness: 61.30% at generation number 41, same fitness 8
# best fitness: 61.30% at generation number 42, same fitness 9
# best fitness: 61.30% at generation number 43, same fitness 10
# best fitness: 61.30% at generation number 44, same fitness 11
# best fitness: 61.70% at generation number 45, same fitness 12
# best fitness: 61.70% at generation number 46, same fitness 1
# best fitness: 61.70% at generation number 47, same fitness 2
# best fitness: 61.70% at generation number 48, same fitness 3
# best fitness: 61.70% at generation number 49, same fitness 4
# best fitness: 61.70% at generation number 50, same fitness 5
# best fitness: 61.70% at generation number 51, same fitness 6
# best fitness: 61.70% at generation number 52, same fitness 7
# best fitness: 61.70% at generation number 53, same fitness 8
# best fitness: 62.10% at generation number 54, same fitness 9
# best fitness: 62.10% at generation number 55, same fitness 1
# best fitness: 62.10% at generation number 56, same fitness 2
# best fitness: 62.10% at generation number 57, same fitness 3
# best fitness: 62.70% at generation number 58, same fitness 4
# best fitness: 62.70% at generation number 59, same fitness 1
# best fitness: 62.70% at generation number 60, same fitness 2
# best fitness: 62.70% at generation number 61, same fitness 3
# best fitness: 62.70% at generation number 62, same fitness 4
# best fitness: 62.70% at generation number 63, same fitness 5
# best fitness: 62.70% at generation number 64, same fitness 6
# best fitness: 62.70% at generation number 65, same fitness 7
# best fitness: 62.70% at generation number 66, same fitness 8
# best fitness: 62.70% at generation number 67, same fitness 9
# best fitness: 62.70% at generation number 68, same fitness 10
# best fitness: 62.70% at generation number 69, same fitness 11
# best fitness: 62.70% at generation number 70, same fitness 12
# best fitness: 62.70% at generation number 71, same fitness 13
# best fitness: 62.70% at generation number 72, same fitness 14
# best fitness: 62.70% at generation number 73, same fitness 15
# best fitness: 62.70% at generation number 74, same fitness 16
# best fitness: 62.70% at generation number 75, same fitness 17
# best fitness: 62.70% at generation number 76, same fitness 18
# best fitness: 62.70% at generation number 77, same fitness 19
# best fitness: 62.70% at generation number 78, same fitness 20
# best fitness: 62.70% at generation number 79, same fitness 21
# best fitness: 62.70% at generation number 80, same fitness 22
# best fitness: 62.70% at generation number 81, same fitness 23
# best fitness: 62.70% at generation number 82, same fitness 24
# best fitness: 62.70% at generation number 83, same fitness 25
# best fitness: 62.70% at generation number 84, same fitness 26
# best fitness: 62.70% at generation number 85, same fitness 27
# best fitness: 62.70% at generation number 86, same fitness 28
# best fitness: 62.70% at generation number 87, same fitness 29
# best fitness: 62.70% at generation number 88, same fitness 30
# best fitness: 62.70% at generation number 89, same fitness 31
# best fitness: 62.70% at generation number 90, same fitness 32
# best fitness: 62.70% at generation number 91, same fitness 33
# best fitness: 62.70% at generation number 92, same fitness 34
# best fitness: 62.70% at generation number 93, same fitness 35
# best fitness: 62.70% at generation number 94, same fitness 36
# best fitness: 62.70% at generation number 95, same fitness 37
# best fitness: 62.70% at generation number 96, same fitness 38
# best fitness: 62.70% at generation number 97, same fitness 39
# best fitness: 62.70% at generation number 98, same fitness 40
# best fitness: 62.70% at generation number 99, same fitness 41
# best fitness: 62.70% at generation number 100, same fitness 42
# best fitness: 62.70% at generation number 101, same fitness 43
# best fitness: 62.70% at generation number 102, same fitness 44
# best fitness: 62.70% at generation number 103, same fitness 45
# best fitness: 62.70% at generation number 104, same fitness 46
# best fitness: 62.70% at generation number 105, same fitness 47
# best fitness: 62.70% at generation number 106, same fitness 48
# best fitness: 62.70% at generation number 107, same fitness 49
# best fitness: 62.70% at generation number 108, same fitness 50
# best fitness: 62.70% at generation number 109, same fitness 51
# best fitness: 62.70% at generation number 110, same fitness 52
# best fitness: 62.70% at generation number 111, same fitness 53
# best fitness: 62.70% at generation number 112, same fitness 54
# best fitness: 62.70% at generation number 113, same fitness 55
# best fitness: 62.70% at generation number 114, same fitness 56
# best fitness: 62.70% at generation number 115, same fitness 57
# best fitness: 62.70% at generation number 116, same fitness 58
# best fitness: 62.70% at generation number 117, same fitness 59
# best fitness: 62.70% at generation number 118, same fitness 60
# best fitness: 62.70% at generation number 119, same fitness 61
# best fitness: 62.70% at generation number 120, same fitness 62
# best fitness: 62.70% at generation number 121, same fitness 63
# best fitness: 62.70% at generation number 122, same fitness 64
# best fitness: 62.70% at generation number 123, same fitness 65
# best fitness: 62.70% at generation number 124, same fitness 66
# best fitness: 62.70% at generation number 125, same fitness 67
# best fitness: 62.70% at generation number 126, same fitness 68
# best fitness: 62.70% at generation number 127, same fitness 69
# best fitness: 62.70% at generation number 128, same fitness 70
# best fitness: 62.70% at generation number 129, same fitness 71
# best fitness: 62.70% at generation number 130, same fitness 72
# best fitness: 62.70% at generation number 131, same fitness 73
# best fitness: 62.70% at generation number 132, same fitness 74
# best fitness: 62.70% at generation number 133, same fitness 75
# best fitness: 62.70% at generation number 134, same fitness 76
# best fitness: 62.70% at generation number 135, same fitness 77
# best fitness: 62.70% at generation number 136, same fitness 78
# best fitness: 62.70% at generation number 137, same fitness 79
# best fitness: 62.70% at generation number 138, same fitness 80
# best fitness: 62.70% at generation number 139, same fitness 81
# best fitness: 62.70% at generation number 140, same fitness 82
# best fitness: 62.70% at generation number 141, same fitness 83
# best fitness: 62.70% at generation number 142, same fitness 84
# best fitness: 62.70% at generation number 143, same fitness 85
# best fitness: 62.70% at generation number 144, same fitness 86
# best fitness: 62.70% at generation number 145, same fitness 87
# best fitness: 62.70% at generation number 146, same fitness 88
# best fitness: 62.70% at generation number 147, same fitness 89
# best fitness: 62.70% at generation number 148, same fitness 90
# best fitness: 62.70% at generation number 149, same fitness 91
# best fitness: 62.70% at generation number 150, same fitness 92
# best fitness: 62.70% at generation number 151, same fitness 93
# best fitness: 62.70% at generation number 152, same fitness 94
# best fitness: 62.70% at generation number 153, same fitness 95
# best fitness: 62.70% at generation number 154, same fitness 96
# best fitness: 62.70% at generation number 155, same fitness 97
# best fitness: 62.70% at generation number 156, same fitness 98
# best fitness: 62.70% at generation number 157, same fitness 99
# best fitness: 62.70% at generation number 158, same fitness 100
# best fitness: 62.70% at generation number 159, same fitness 101
# best fitness: 62.70% at generation number 160, same fitness 102
# best fitness: 62.70% at generation number 161, same fitness 103
# best fitness: 62.70% at generation number 162, same fitness 104
# best fitness: 62.70% at generation number 163, same fitness 105
# best fitness: 62.70% at generation number 164, same fitness 106
# best fitness: 62.70% at generation number 165, same fitness 107
# best fitness: 62.70% at generation number 166, same fitness 108
# best fitness: 62.70% at generation number 167, same fitness 109
# best fitness: 62.70% at generation number 168, same fitness 110
# best fitness: 62.70% at generation number 169, same fitness 111
# best fitness: 62.70% at generation number 170, same fitness 112
# best fitness: 62.70% at generation number 171, same fitness 113
# best fitness: 62.70% at generation number 172, same fitness 114
# best fitness: 62.70% at generation number 173, same fitness 115
# best fitness: 62.70% at generation number 174, same fitness 116
# best fitness: 62.70% at generation number 175, same fitness 117
# best fitness: 62.70% at generation number 176, same fitness 118
# best fitness: 62.70% at generation number 177, same fitness 119
# best fitness: 62.70% at generation number 178, same fitness 120
# best fitness: 62.70% at generation number 179, same fitness 121
# best fitness: 62.70% at generation number 180, same fitness 122
# best fitness: 62.70% at generation number 181, same fitness 123
# best fitness: 62.70% at generation number 182, same fitness 124
# best fitness: 62.70% at generation number 183, same fitness 125
# best fitness: 62.70% at generation number 184, same fitness 126
# best fitness: 62.70% at generation number 185, same fitness 127
# best fitness: 62.70% at generation number 186, same fitness 128
# best fitness: 62.70% at generation number 187, same fitness 129
# best fitness: 62.70% at generation number 188, same fitness 130
# best fitness: 62.70% at generation number 189, same fitness 131
# best fitness: 62.70% at generation number 190, same fitness 132
# best fitness: 62.70% at generation number 191, same fitness 133
# best fitness: 62.70% at generation number 192, same fitness 134
# best fitness: 62.70% at generation number 193, same fitness 135
# best fitness: 62.70% at generation number 194, same fitness 136
# best fitness: 62.70% at generation number 195, same fitness 137
# best fitness: 62.70% at generation number 196, same fitness 138
# best fitness: 62.70% at generation number 197, same fitness 139
# best fitness: 62.70% at generation number 198, same fitness 140
# best fitness: 62.70% at generation number 199, same fitness 141
# best fitness: 62.70% at generation number 200, same fitness 142
# best fitness: 62.70% at generation number 201, same fitness 143
# best fitness: 62.70% at generation number 202, same fitness 144
# best fitness: 62.70% at generation number 203, same fitness 145
# best fitness: 62.70% at generation number 204, same fitness 146
# best fitness: 62.70% at generation number 205, same fitness 147
# best fitness: 62.70% at generation number 206, same fitness 148
# best fitness: 62.70% at generation number 207, same fitness 149
# best fitness: 62.70% at generation number 208, same fitness 150
# all fitness call: 6370
